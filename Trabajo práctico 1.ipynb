# %% [markdown]
# <a href="https://colab.research.google.com/github/AGG126/Aula-F-sica-3/blob/main/Trabajo%20pr%C3%A1ctico%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math

# %% [markdown]
# **Ejercicio 1**. Una onda transversal se propaga en una cuerda con una velocidad de 10 m/s y a una longitud de onda de 2 m. Calcular la frecuencia y el período de la onda.
#
# ![onda transversal.png](data:image/png;base64,...)

# %%
# Código de resolución ejercicio 1
v = 10  # Velocidad de propagación (m/s)
lambda_wave = 2  # Longitud de onda (m)

f = v / lambda_wave  # Frecuencia (Hz)
T = 1 / f  # Período (s)

# Mostrar ambas ecuaciones en una misma línea
display(Math(f"f = \\frac{{v}}{{\\lambda}} = \\frac{{{v}}}{{{lambda_wave}}} = {f:.2f}\\text{{ Hz}}"))
print ('')
display(Math(f"T = \\frac{{1}}{{f}} = \\frac{{1}}{{{f:.2f}}} = {T:.4f}\\text{{ s}}"))
# Out:
# $\displaystyle f = \frac{v}{\lambda} = \frac{10}{2} = 5.00\text{ Hz}$
# $\displaystyle T = \frac{1}{f} = \frac{1}{5.00} = 0.2000\text{ s}$

# %% [markdown]
# **Ejercicio 2.** Considerando que la luz visible tiene una longitud de onda de aproximadamente 500 nm, calcular su frecuencia en el vacío.
# ![espectro_em.png](data:image/png;base64,...)

# %%
c = 3.0e8  # Velocidad de la luz (m/s)
lambda_light = 500e-9  # Longitud de onda (m)
f_light = c / lambda_light  # Frecuencia de la onda electromagnética (Hz)

display(Math(f"f_{{light}} = \\frac{{c}}{{\\lambda}} = \\frac{{{c}}}{{{lambda_light}}} = {f_light:.2e}\\text{{ Hz}}"))
# Out:
# $\displaystyle f_{light} = \frac{c}{\lambda} = \frac{300000000.0}{5e-07} = 6.00e+14\text{ Hz}$

# %% [markdown]
# **Ejercicio 3.** Representar gráficamente la forma de la onda en función de la posición y el tiempo.

# %%
x = np.linspace(0, 4 * lambda_wave, 500)  # Posición en la cuerda (m)
t = 0  # Tiempo inicial
y = np.sin(2 * np.pi * (x / lambda_wave - t / T))  # Ecuación de la onda

plt.figure(figsize=(8, 4))
plt.plot(x, y, label='Onda transversal en la cuerda')
plt.xlabel('Posición (m)')
plt.ylabel('Desplazamiento (m)')
plt.title('Representación de una onda transversal')
plt.legend()
plt.grid()
plt.show()
